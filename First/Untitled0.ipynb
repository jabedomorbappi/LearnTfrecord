# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp /content/drive/MyDrive/LearnAboutTfrecord/First/cars.tfrecords ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/cars.tfrecords

# %%
import tensorflow as tf

def get_feature_description():
  feature_description = {
      'region': tf.io.FixedLenFeature([], tf.string),
      'price': tf.io.FixedLenFeature([], tf.int64),
      'year': tf.io.FixedLenFeature([], tf.float32),
      'fuel': tf.io.FixedLenFeature([], tf.string),
      'odometer': tf.io.FixedLenFeature([], tf.float32),
      'lat': tf.io.FixedLenFeature([], tf.float32),
      'type': tf.io.FixedLenFeature([], tf.string)
  }
  return feature_description

def parse_example(record):
  return tf.io.parse_single_example(record, get_feature_description())

cars_dataset = tf.data.TFRecordDataset("/content/drive/MyDrive/LearnAboutTfrecord/First/cars.tfrecords")
parsed_tfrecords = cars_dataset.map(map_func=parse_example)

# %%
parsed_tfrecords
# Out:
# <_MapDataset element_spec={'fuel': TensorSpec(shape=(), dtype=tf.string, name=None), 'lat': TensorSpec(shape=(), dtype=tf.float32, name=None), 'odometer': TensorSpec(shape=(), dtype=tf.float32, name=None), 'price': TensorSpec(shape=(), dtype=tf.int64, name=None), 'region': TensorSpec(shape=(), dtype=tf.string, name=None), 'type': TensorSpec(shape=(), dtype=tf.string, name=None), 'year': TensorSpec(shape=(), dtype=tf.float32, name=None)}>

# %%
for i in parsed_tfrecords.take(5):
  print(i)
# Out:
# {'fuel': <tf.Tensor: shape=(), dtype=string, numpy=b'gas'>, 'lat': <tf.Tensor: shape=(), dtype=float32, numpy=32.59>, 'odometer': <tf.Tensor: shape=(), dtype=float32, numpy=57923.0>, 'price': <tf.Tensor: shape=(), dtype=int64, numpy=33590>, 'region': <tf.Tensor: shape=(), dtype=string, numpy=b'auburn'>, 'type': <tf.Tensor: shape=(), dtype=string, numpy=b'pickup'>, 'year': <tf.Tensor: shape=(), dtype=float32, numpy=2014.0>}
# {'fuel': <tf.Tensor: shape=(), dtype=string, numpy=b'gas'>, 'lat': <tf.Tensor: shape=(), dtype=float32, numpy=32.59>, 'odometer': <tf.Tensor: shape=(), dtype=float32, numpy=71229.0>, 'price': <tf.Tensor: shape=(), dtype=int64, numpy=22590>, 'region': <tf.Tensor: shape=(), dtype=string, numpy=b'auburn'>, 'type': <tf.Tensor: shape=(), dtype=string, numpy=b'pickup'>, 'year': <tf.Tensor: shape=(), dtype=float32, numpy=2010.0>}
# {'fuel': <tf.Tensor: shape=(), dtype=string, numpy=b'gas'>, 'lat': <tf.Tensor: shape=(), dtype=float32, numpy=32.59>, 'odometer': <tf.Tensor: shape=(), dtype=float32, numpy=19160.0>, 'price': <tf.Tensor: shape=(), dtype=int64, numpy=39590>, 'region': <tf.Tensor: shape=(), dtype=string, numpy=b'auburn'>, 'type': <tf.Tensor: shape=(), dtype=string, numpy=b'pickup'>, 'year': <tf.Tensor: shape=(), dtype=float32, numpy=2020.0>}
# {'fuel': <tf.Tensor: shape=(), dtype=string, numpy=b'gas'>, 'lat': <tf.Tensor: shape=(), dtype=float32, numpy=32.59>, 'odometer': <tf.Tensor: shape=(), dtype=float32, numpy=41124.0>, 'price': <tf.Tensor: shape=(), dtype=int64, numpy=30990>, 'region': <tf.Tensor: shape=(), dtype=string, numpy=b'auburn'>, 'type': <tf.Tensor: shape=(), dtype=string, numpy=b'pickup'>, 'year': <tf.Tensor: shape=(), dtype=float32, numpy=2017.0>}
# {'fuel': <tf.Tensor: shape=(), dtype=string, numpy=b'gas'>, 'lat': <tf.Tensor: shape=(), dtype=float32, numpy=32.592>, 'odometer': <tf.Tensor: shape=(), dtype=float32, numpy=128000.0>, 'price': <tf.Tensor: shape=(), dtype=int64, numpy=15000>, 'region': <tf.Tensor: shape=(), dtype=string, numpy=b'auburn'>, 'type': <tf.Tensor: shape=(), dtype=string, numpy=b'truck'>, 'year': <tf.Tensor: shape=(), dtype=float32, numpy=2013.0>}
